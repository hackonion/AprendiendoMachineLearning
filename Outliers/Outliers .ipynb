# %%
import matplotlib.pyplot as plt 
import numpy as np 
from math import pi

# %%
#outlier one dimension
ages = np.array([22,22,23,23,23,23,26,27,27,28,30,30,30,30,31,32,33,34,80])
ages_unique, counts = np.unique(edades, return_counts=True)

sizes = counts*100
colors = ['blue']*len(ages_unique)
colors[-1] = 'red'

plt.axhline(1,color='k',linestyle='--')
plt.scatter(ages_unique, np.ones(len(ages_unique)), s=sizes, color=colors)
plt.yticks([])
plt.show()

# %%
#outlier two dimension
annual_salary_miles = np.array([16,20,15,21,19,17,33,22,31,32,56,30,22,31,30,16,2,22,23])
mean = annual_salary_miles.mean()
std_x = annual_salary_miles*2
mean_y = ages.mean()
std_y = ages.std()*2

# %%
#Outliers 3D
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection='3d')
 
mount_purchases = np.array([1,2,1,20,1,0,3,2,3,0,5,3,2,1,0,1,2,2,2])
media_z = (mount_purchases).mean()
std_z = (mount_purchases).std()*2
 
for index, x in enumerate(mount_purchases):
    if abs(x-media_z) > std_z:
        colors[index] = 'red'
 
ax.scatter(ages, annual_salary_miles, mount_purchases, s=20, c=colors)
plt.xlabel('age')
plt.ylabel('annual purchases (miles)')
ax.set_zlabel('mount purchases')
 
plt.show()

# %%
#Outliers pyod
from pyod.models.knn import KNN
import pandas as pd
 
X = pd.DataFrame(data={'edad':ages,'salario':annual_salary_miles, 'compras':compras_mes})
 
clf = KNN(contamination=0.18)
clf.fit(X)
y_pred = clf.predict(X)
X[y_pred == 1]
# Out:
#     edad  salario  compras
# 3     23       21       20
# 10    30       56        5
# 16    33        2        2
# 18    80       23        2
